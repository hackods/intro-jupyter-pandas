# %%
a = 1
b = 2

# %%
c = a + b
c
# Out:
# 3

# %% [markdown]
# ## Esto no se hace

# %%
a = 1
 b = 2
# Out:
#   Cell In[3], line 2
#     b = 2
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ## Esto es lo mejor
# - Celdas alineadas
# - Código agrupado
# - No son nombres alusivos

# %%
a = 1
b = 2
c = a + b
